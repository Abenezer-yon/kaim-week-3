# %%
import os, sys

notebook_dir = os.getcwd()

#add path
sys.path.append(os.path.abspath(os.path.join(notebook_dir, '..')))

# %%
from scripts.data_preprocessing import *
from scripts.eda import *
from scripts.visualization import *

# %%
# change the text file format to csv    
data = "../../Data/MachineLearningRating_v3/MachineLearningRating_v3.txt"
changed_data = change_to_csv(data)
changed_data
# Out:
# c:\Users\hp\Desktop\LEARN\10Academy\kaim-week-3\scripts\data_preprocessing.py:8: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(input_file, delimiter='|') # Delimeter
# File successfully converted and saved as ../../Data/MachineLearningRating_v3/MachineLearningRating_v3.csv
# '../../Data/MachineLearningRating_v3/MachineLearningRating_v3.csv'

# %%
# Takes the change data and reads it to print it out
# dataCsv =load_data(changed_data)
# dataCsv.head(5)

# Loads the csv file and prints it out
dataCsv = "../../Data/MachineLearningRating_v3/MachineLearningRating_v3.csv"
loaded_data =load_data(dataCsv)
loaded_data.head(5)
# Out:
# c:\Users\hp\Desktop\LEARN\10Academy\kaim-week-3\scripts\data_preprocessing.py:19: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(filepath)
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# ...

# %%
# Checks the data types of the data
check_data_types(loaded_data)

# Checks for missing values in the data
check_missing_values(loaded_data)
# Out:
# UnderwrittenCoverID               0
# PolicyID                          0
# TransactionMonth                  0
# IsVATRegistered                   0
# Citizenship                       0
# LegalType                         0
# Title                             0
# Language                          0
# Bank                         145961
# AccountType                   40232
# MaritalStatus                  8259
# Gender                         9536
# Country                           0
# Province                          0
# PostalCode                        0
# MainCrestaZone                    0
# SubCrestaZone                     0
# ItemType                          0
# mmcode                          552
# VehicleType                     552
# RegistrationYear                  0
# make                            552
# Model                           552
# Cylinders                       552
# cubiccapacity                   552
# kilowatts                       552
# ...

# %%
# Calculate descriptive statistics for numerical features.
descriptive_statistics(loaded_data)
# Out:
#        UnderwrittenCoverID      PolicyID    PostalCode        mmcode  \
# count         1.000098e+06  1.000098e+06  1.000098e+06  9.995460e+05
# mean          1.048175e+05  7.956682e+03  3.020601e+03  5.487770e+07
# std           6.329371e+04  5.290039e+03  2.649854e+03  1.360381e+07
# min           1.000000e+00  1.400000e+01  1.000000e+00  4.041200e+06
# 25%           5.514300e+04  4.500000e+03  8.270000e+02  6.005692e+07
# 50%           9.408300e+04  7.071000e+03  2.000000e+03  6.005842e+07
# 75%           1.391900e+05  1.107700e+04  4.180000e+03  6.005842e+07
# max           3.011750e+05  2.324600e+04  9.870000e+03  6.506535e+07
#
#        RegistrationYear      Cylinders  cubiccapacity      kilowatts  \
# count      1.000098e+06  999546.000000  999546.000000  999546.000000
# mean       2.010225e+03       4.046642    2466.743258      97.207919
# std        3.261391e+00       0.294020     442.800640      19.393256
# ...

# %%
# Create histograms for numerical columns and bar charts for categorical columns.
univariate_analysis(loaded_data, ["cubiccapacity"], ["CoverCategory"])

# %%
# Explore correlation between TotalPremium and TotalClaims.
correlation_analysis(loaded_data)

# %%
# Create a box plot to detect outliers.
box_plot(loaded_data, "cubiccapacity")

# %%
print(loaded_data.columns)

# %%
# Create three insightful plots.
creative_plots(loaded_data)

# %%
from scripts.segmentation import *

# %%
data_segmentation(loaded_data)
# Out:
# (Empty DataFrame
#  Columns: [UnderwrittenCoverID, PolicyID, TransactionMonth, IsVATRegistered, Citizenship, LegalType, Title, Language, Bank, AccountType, MaritalStatus, Gender, Country, Province, PostalCode, MainCrestaZone, SubCrestaZone, ItemType, mmcode, VehicleType, RegistrationYear, make, Model, Cylinders, cubiccapacity, kilowatts, bodytype, NumberOfDoors, VehicleIntroDate, CustomValueEstimate, AlarmImmobiliser, TrackingDevice, CapitalOutstanding, NewVehicle, WrittenOff, Rebuilt, Converted, CrossBorder, NumberOfVehiclesInFleet, SumInsured, TermFrequency, CalculatedPremiumPerTerm, ExcessSelected, CoverCategory, CoverType, CoverGroup, Section, Product, StatutoryClass, StatutoryRiskType, TotalPremium, TotalClaims]
#  Index: []
#
#  [0 rows x 52 columns],
#  Empty DataFrame
# ...

# %%
group_a, group_b = data_segmentation(loaded_data)
if group_a is None or group_b is None:
    print("Data segmentation failed due to missing columns.")
else:
    # Statistical testing
    p_value_provinces = statistical_testing(loaded_data)
    p_value_zip_codes = test_for_numerical(group_a, group_b)

    # Collect p-values for analysis and reporting
    p_values = [p_value_provinces, p_value_zip_codes]

    # Analyze and report findings
    analyze_and_report(p_values)
# Out:
# Chi-squared test p-value for risk differences across provinces: 1.0
# Fail to reject the null hypothesis: No significant risk differences across provinces.
# T-test p-value for profit margin differences between groups: nan
# Fail to reject the null hypothesis: No significant profit margin differences between groups.
# Risk differences across provinces: Fail to reject null hypothesis.
# Profit margin differences between groups: Fail to reject null hypothesis.
# c:\Users\hp\Desktop\LEARN\10Academy\kaim-week-3\scripts\segmentation.py:44: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   t_stat, p_value = ttest_ind(total_premium_a, total_premium_b)

# %%
from scripts.evaluation_and_performance import *

# %%
X_train, X_test, y_train, y_test = prepare_data(loaded_data)

print(X_train, X_test, y_train, y_test)
# Train models
trained_models = train_models(X_train, y_train)

# Evaluate models
evaluate_models(trained_models, X_test, y_test)
